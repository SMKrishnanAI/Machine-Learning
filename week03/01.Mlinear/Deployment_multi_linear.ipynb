# %%
import pickle

# %%
loaded_module=pickle.load(open("finalized_model_Multi_linear.sav","rb"))

# %%
rNd_spend_input=float(input("R&D: "))
admin_input=float(input("Admin: "))
mark_input=float(input("Marketing: "))
fol_input=int(input("State_flo 0 or 1:"))
new_input=int(input("State_new 0 or 1:"))
# Out:
# R&D:  2000
# Admin:  400
# Marketing:  4000
# State_flo 0 or 1: 0
# State_new 0 or 1: 0

# %%
result=loaded_module.predict([[rNd_spend_input,admin_input,mark_input,fol_input,new_input]])
# Out:
# C:\Users\Muthukrishnan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[44121.68953328]])
